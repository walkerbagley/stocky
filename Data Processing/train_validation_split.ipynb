# %%
# Imports
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# %%
data = pd.read_csv('merged_datasets.csv')

# load in testing data to normalize
testing = pd.read_csv("testing_data.csv")

data.head(5)
# Out:
#          Date     Price      Open      High       Low Change %   Score 1  \
# 0  2016-07-01  2,102.95  2,099.34  2,108.71  2,097.90    0.19%  0.219861
# 1  2016-06-30  2,098.86  2,073.17  2,098.94  2,070.00    1.36%  0.503280
# 2  2016-06-29  2,070.77  2,042.69  2,073.13  2,042.69    1.70%  0.503280
# 3  2016-06-28  2,036.09  2,006.67  2,036.09  2,006.67    1.78%  0.926120
# 4  2016-06-27  2,000.54  2,031.45  2,031.45  1,991.68   -1.81%  0.388214
#
#     Score 2   Score 3   Score 4   Score 5  Average Score
# 0  0.477043  0.794071  0.063050  0.352774       0.381360
# 1  0.292724  0.707632  0.049016  0.191895       0.348909
# 2  0.157116  0.899019  0.256470  0.279351       0.419047
# 3  0.269995  0.754411  0.665073  0.110896       0.545299
# 4  0.642193  0.179438  0.451060  0.827122       0.497605

# %%
# get data in sequence
data = data.sort_values('Date')
data = data.reset_index(drop=True)

data.head(5)
# Out:
#          Date     Price      Open      High       Low Change %   Score 1  \
# 0  2008-06-09  1,361.76  1,360.83  1,370.63  1,350.62    0.08%  0.503280
# 1  2008-06-10  1,358.44  1,358.98  1,366.84  1,351.56   -0.24%  0.376163
# 2  2008-06-11  1,335.49  1,357.09  1,357.09  1,335.47   -1.69%  0.341486
# 3  2008-06-12  1,339.87  1,335.78  1,353.03  1,331.29    0.33%  0.092744
# 4  2008-06-13  1,360.03  1,341.81  1,360.03  1,341.71    1.50%  0.477043
#
#     Score 2   Score 3   Score 4   Score 5  Average Score
# 0  0.179438  0.745665  0.618345  0.516398       0.512625
# 1  0.198505  0.503280  0.503280  0.412824       0.398810
# 2  0.143438  0.309147  0.341486  0.503280       0.327767
# 3  0.252148  0.769360  0.107541  0.260894       0.296537
# 4  0.058372  0.568363  0.133676  0.503280       0.348147

# %%
print(data.dtypes)
# Out:
# Date              object
# Price             object
# Open              object
# High              object
# Low               object
# Change %          object
# Score 1          float64
# Score 2          float64
# Score 3          float64
# Score 4          float64
# Score 5          float64
# Average Score    float64
# dtype: object

# %%
cols = ['Price', 'Open', 'High', 'Low', 'Change %']

for col in cols:
    for i, entry in enumerate(data[col]):
        if type(entry) == str:
            entry = entry.replace(',', '')
            entry = entry.replace('%', '')
        entry = float(entry)
        data.at[i, col] = entry

data.head(5)
# Out:
#          Date    Price     Open     High      Low Change %   Score 1  \
# 0  2008-06-09  1361.76  1360.83  1370.63  1350.62     0.08  0.503280
# 1  2008-06-10  1358.44  1358.98  1366.84  1351.56    -0.24  0.376163
# 2  2008-06-11  1335.49  1357.09  1357.09  1335.47    -1.69  0.341486
# 3  2008-06-12  1339.87  1335.78  1353.03  1331.29     0.33  0.092744
# 4  2008-06-13  1360.03  1341.81  1360.03  1341.71      1.5  0.477043
#
#     Score 2   Score 3   Score 4   Score 5  Average Score
# 0  0.179438  0.745665  0.618345  0.516398       0.512625
# 1  0.198505  0.503280  0.503280  0.412824       0.398810
# 2  0.143438  0.309147  0.341486  0.503280       0.327767
# 3  0.252148  0.769360  0.107541  0.260894       0.296537
# 4  0.058372  0.568363  0.133676  0.503280       0.348147

# %%
for col in cols:
    for i, entry in enumerate(testing[col]):
        if type(entry) == str:
            entry = entry.replace(',', '')
            entry = entry.replace('%', '')
        entry = float(entry)
        testing.at[i, col] = entry

testing.head(5)
# Out:
#          Date   Price    Open    High     Low Change %   Score 1   Score 2  \
# 0  2023-11-03  4358.3  4334.2  4373.6  4334.2     0.94  0.490560  0.628980
# 1  2023-11-02  4317.8  4268.3  4319.7  4268.3     1.89  0.490560  0.326671
# 2  2023-11-01  4237.9  4201.3  4245.6  4197.7     1.05  0.490560  0.807209
# 3  2023-10-31  4193.8  4171.3  4195.6  4153.1     0.65  0.447816  0.000000
# 4  2023-10-30  4166.8  4139.4  4177.5  4132.9      1.2  0.940479  0.490560
#
#     Score 3   Score 4   Score 5  Average Score
# 0  0.490560  0.533304  0.753779       0.579436
# 1  0.628980  0.678811  0.365262       0.498057
# 2  0.547423  0.602569  0.782183       0.645989
# 3  0.490560  0.561431  0.773268       0.454615
# 4  0.060794  0.490560  0.314379       0.459354

# %%
numTrain = int(len(data) * 0.8)
numVal = len(data) - numTrain
print(numTrain, numVal, len(data))
# Out:
# 1625 407 2032

# %%
training = data.iloc[0:numTrain]
print(len(training))

validation = data.iloc[numTrain:len(data)]
validation = validation.reset_index(drop=True)
print(len(validation))
# Out:
# 1625
# 407

# %%
display(training)
# Out:
#             Date    Price     Open     High      Low Change %   Score 1  \
# 0     2008-06-09  1361.76  1360.83  1370.63  1350.62     0.08  0.503280
# 1     2008-06-10  1358.44  1358.98  1366.84  1351.56    -0.24  0.376163
# 2     2008-06-11  1335.49  1357.09  1357.09  1335.47    -1.69  0.341486
# 3     2008-06-12  1339.87  1335.78  1353.03  1331.29     0.33  0.092744
# 4     2008-06-13  1360.03  1341.81  1360.03  1341.71      1.5  0.477043
# ...          ...      ...      ...      ...      ...      ...       ...
# 1620  2014-11-12  2038.25  2037.75  2040.33  2031.95    -0.07  0.376163
# 1621  2014-11-13  2039.33  2039.21  2046.18  2030.44     0.05  0.503280
# 1622  2014-11-14  2039.82  2039.74  2042.22   2035.2     0.02  0.503280
# 1623  2014-11-17  2041.32  2038.29  2043.07  2034.46     0.07  0.477043
# 1624  2014-11-18   2051.8  2041.48  2056.08  2041.48     0.51  0.503280
#
#        Score 2   Score 3   Score 4   Score 5  Average Score
# ...

# %%
display(validation)
# Out:
#            Date    Price     Open     High      Low Change %   Score 1  \
# 0    2014-11-19  2048.72  2051.16  2052.14  2040.37    -0.15  0.503280
# 1    2014-11-20  2052.75  2045.87  2053.84  2040.49      0.2  0.024152
# 2    2014-11-21   2063.5  2057.46  2071.46  2056.75     0.52  0.022728
# 3    2014-11-24  2069.41  2065.07  2070.17  2065.07     0.29  0.503280
# 4    2014-11-25  2067.03  2070.15  2074.21  2064.75    -0.12  0.911069
# ..          ...      ...      ...      ...      ...      ...       ...
# 402  2016-06-27  2000.54  2031.45  2031.45  1991.68    -1.81  0.388214
# 403  2016-06-28  2036.09  2006.67  2036.09  2006.67     1.78  0.926120
# 404  2016-06-29  2070.77  2042.69  2073.13  2042.69      1.7  0.503280
# 405  2016-06-30  2098.86  2073.17  2098.94   2070.0     1.36  0.503280
# 406  2016-07-01  2102.95  2099.34  2108.71   2097.9     0.19  0.219861
#
#       Score 2   Score 3   Score 4   Score 5  Average Score
# ...

# %%
display(testing)
# Out:
#           Date   Price    Open    High     Low Change %   Score 1   Score 2  \
# 0   2023-11-03  4358.3  4334.2  4373.6  4334.2     0.94  0.490560  0.628980
# 1   2023-11-02  4317.8  4268.3  4319.7  4268.3     1.89  0.490560  0.326671
# 2   2023-11-01  4237.9  4201.3  4245.6  4197.7     1.05  0.490560  0.807209
# 3   2023-10-31  4193.8  4171.3  4195.6  4153.1     0.65  0.447816  0.000000
# 4   2023-10-30  4166.8  4139.4  4177.5  4132.9      1.2  0.940479  0.490560
# 5   2023-10-27  4117.4  4152.9  4156.7  4103.8    -0.48  0.490560  0.490560
# 6   2023-10-26  4137.2  4176.0  4183.6  4127.9    -1.18  0.490560  0.339295
# 7   2023-10-25  4186.8  4232.4  4232.4  4181.4    -1.43  0.420630  0.602569
# 8   2023-10-24  4247.7  4235.8  4259.4  4219.4     0.73  0.490560  0.490560
# 9   2023-10-23  4217.0  4210.4  4255.8  4189.2    -0.17  0.490560  0.490560
# 10  2023-10-20  4224.2  4273.9  4276.6  4223.0    -1.26  0.490560  0.083550
# ...

# %%
# Apply scaling to each column in cols
for col in cols:
    train_scaler = MinMaxScaler()
    val_scaler = MinMaxScaler()
    test_scaler = MinMaxScaler()
    training[col] = train_scaler.fit_transform(training[[col]])
    validation[col] = val_scaler.fit_transform(validation[[col]])
    testing[col] = test_scaler.fit_transform(testing[[col]])
# Out:
# <ipython-input-29-5c68ad62403d>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   training[col] = train_scaler.fit_transform(training[[col]])
# <ipython-input-29-5c68ad62403d>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   training[col] = train_scaler.fit_transform(training[[col]])
# <ipython-input-29-5c68ad62403d>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
display(training)
# Out:
#             Date     Price      Open      High       Low  Change %   Score 1  \
# 0     2008-06-09  0.498251  0.500330  0.496293  0.497443  0.442018  0.503280
# 1     2008-06-10  0.495837  0.498972  0.493508  0.498127  0.426492  0.376163
# 2     2008-06-11  0.479150  0.497585  0.486343  0.486422  0.356138  0.341486
# 3     2008-06-12  0.482334  0.481941  0.483359  0.483382  0.454148  0.092744
# 4     2008-06-13  0.496993  0.486368  0.488503  0.490962  0.510917  0.477043
# ...          ...       ...       ...       ...       ...       ...       ...
# 1620  2014-11-12  0.990147  0.997262  0.988426  0.993068  0.434740  0.376163
# 1621  2014-11-13  0.990933  0.998334  0.992725  0.991969  0.440563  0.503280
# 1622  2014-11-14  0.991289  0.998723  0.989815  0.995432  0.439107  0.503280
# 1623  2014-11-17  0.992380  0.997658  0.990440  0.994893  0.441533  0.477043
# 1624  2014-11-18  1.000000  1.000000  1.000000  1.000000  0.462882  0.503280
#
# ...

# %%
display(validation)
# Out:
#            Date     Price      Open      High       Low  Change %   Score 1  \
# 0    2014-11-19  0.727911  0.733297  0.712985  0.728795  0.483418  0.503280
# 1    2014-11-20  0.741267  0.715484  0.718893  0.729175  0.528061  0.024152
# 2    2014-11-21  0.776894  0.754512  0.780133  0.780637  0.568878  0.022728
# 3    2014-11-24  0.796480  0.780139  0.775650  0.806969  0.539541  0.503280
# 4    2014-11-25  0.788593  0.797245  0.789691  0.805956  0.487245  0.911069
# ..          ...       ...       ...       ...       ...       ...       ...
# 402  2016-06-27  0.568238  0.666925  0.641075  0.574693  0.271684  0.388214
# 403  2016-06-28  0.686054  0.583479  0.657201  0.622136  0.729592  0.926120
# 404  2016-06-29  0.800988  0.704775  0.785938  0.736137  0.719388  0.503280
# 405  2016-06-30  0.894081  0.807415  0.875643  0.822572  0.676020  0.503280
# 406  2016-07-01  0.907636  0.895541  0.909600  0.910875  0.526786  0.219861
#
# ...

# %%
display(testing)
# Out:
#           Date     Price      Open      High       Low  Change %   Score 1  \
# 0   2023-11-03  0.928324  0.806625  0.915576  0.954037  0.713855  0.490560
# 1   2023-11-02  0.772254  0.533747  0.688054  0.681159  1.000000  0.490560
# 2   2023-11-01  0.464355  0.256315  0.375264  0.388820  0.746988  0.490560
# 3   2023-10-31  0.294412  0.132091  0.164204  0.204141  0.626506  0.447816
# 4   2023-10-30  0.190366  0.000000  0.087801  0.120497  0.792169  0.940479
# 5   2023-10-27  0.000000  0.055901  0.000000  0.000000  0.286145  0.490560
# 6   2023-10-26  0.076301  0.151553  0.113550  0.099793  0.075301  0.490560
# 7   2023-10-25  0.267437  0.385093  0.319544  0.321325  0.000000  0.420630
# 8   2023-10-24  0.502119  0.399172  0.433516  0.478675  0.650602  0.490560
# 9   2023-10-23  0.383815  0.293996  0.418320  0.353623  0.379518  0.490560
# 10  2023-10-20  0.411561  0.556936  0.506121  0.493582  0.051205  0.490560
# ...

# %%
training.to_csv("normalized_training_data.csv", index=False)
validation.to_csv("normalized_validation_data.csv", index=False)
testing.to_csv("normalized_testing_data.csv", index=False)
